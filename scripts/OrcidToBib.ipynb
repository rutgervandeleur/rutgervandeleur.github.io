# %%
orcid = '0000-0002-4779-5870' # Fill your orcid here

# %%
import requests

# %% [markdown]
# We use the `/works` api to list all works related to the orcid. This gives a summary of all works, so citation information is not included. We collect the `put-code` of all works to retrieve the citation information later.

# %%
response = requests.get('https://pub.orcid.org/v3.0/{}/works'.format(orcid),
                        headers={"Accept": "application/orcid+json" })
record = response.json()

# %%
put_codes = []
for work in record['group']:
    put_code = work['work-summary'][0]['put-code']
    put_codes.append(put_code)

# %% [markdown]
# We use the `/<orcid>/work/<put-code>` endpoint to retrieve the citation information for each record.

# %%
citations = []
for put_code in put_codes:
    response = requests.get('https://pub.orcid.org/v3.0/{}/work/{}'.format(orcid, put_code),
                            headers={"Accept": "application/orcid+json" })
    work = response.json()
    print(work)
    if work['citation'] is not None:
        citations.append(work['citation']['citation-value'])
# Out:
# {'created-date': {'value': 1727623676984}, 'last-modified-date': {'value': 1727623676984}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 168523639, 'path': '/0000-0002-4779-5870/work/168523639', 'title': {'title': {'value': 'On the design and development of a handheld electrocardiogram device in a clinical setting.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'Frontiers in digital health'}, 'short-description': 'Cardiovascular diseases (CVDs) are a global burden that requires attention. For the detection and diagnosis of CVDs, the 12-lead ECG is a key tool. With technological advancements, ECG devices are becoming smaller and available for home use. Most of these devices contain a limited number of leads and are aimed to detect atrial fibrillation (AF). To investigate whether a four-electrode arrangement could provide enough information to diagnose other CVDs, further research is necessary. At the University Medical Center Utrecht in a multidisciplinary team, we developed the miniECG, a four-electrode ECG handheld system for scientific research in clinical environments (TRL6). This paper describes the process followed during the development of the miniECG. From assembling a multidisciplinary team, which includes engineers, cardiologists, and clinical physicians to the contribution of team members in the design input, design, and testing for safety and functionality of the device. Finally, we detail how the development process was composed by iterative design steps based on user input and intended use evolution. The miniECG is a device compliant for scientific research with patients within Dutch Medical Centers. We believe that hospital-based development led to a streamlined process, which could be applied for the design and development of other technologies used for scientific research in clinical environments.', 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2024'}, 'month': {'value': '08'}, 'day': {'value': '09'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '39184339', 'external-id-normalized': {'value': '39184339', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://pubmed.ncbi.nlm.nih.gov/39184339'}, 'external-id-relationship': 'self'}, {'external-id-type': 'pmc', 'external-id-value': 'PMC11341539', 'external-id-normalized': {'value': '11341539', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://europepmc.org/article/pmc/PMC11341539'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.3389/fdgth.2024.1403457', 'external-id-normalized': {'value': '10.3389/fdgth.2024.1403457', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.3389/fdgth.2024.1403457'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://europepmc.org/articles/PMC11341539'}, 'contributors': {'contributor': [{'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Zepeda-Echavarria A'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Ratering Arntz NCM'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Westra AH'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orci ...
# {'created-date': {'value': 1708715566199}, 'last-modified-date': {'value': 1719823783241}, 'source': {'source-orcid': None, 'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913', 'path': '0000-0001-9884-1913', 'host': 'orcid.org'}, 'source-name': {'value': 'Crossref'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 153903616, 'path': '/0000-0002-4779-5870/work/153903616', 'title': {'title': {'value': 'ECG-only explainable deep learning algorithm predicts the risk for malignant ventricular arrhythmia in phospholamban cardiomyopathy'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'Heart Rhythm'}, 'short-description': None, 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2024'}, 'month': {'value': '07'}, 'day': None}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.1016/j.hrthm.2024.02.038', 'external-id-normalized': {'value': '10.1016/j.hrthm.2024.02.038', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1016/j.hrthm.2024.02.038'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1016/j.hrthm.2024.02.038'}, 'contributors': {'contributor': [{'contributor-orcid': None, 'credit-name': {'value': 'Rutger R. van de Leur'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Remco de Brouwer'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Hidde Bleijendaal'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Tom E. Verstraelen'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Belend Mahmoud'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Ana Perez-Matos'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Cathelijne Dickhoff'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Bas A. Schoonderwoerd'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Tjeerd Germans'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Arjan Houweling'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Paul A. van der Zwaag'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Moniek G.P.J. Cox'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'J. Peter van Tintelen'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Anneline S.J.M. te Riele'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-rol ...
# {'created-date': {'value': 1705357518650}, 'last-modified-date': {'value': 1710721661122}, 'source': {'source-orcid': None, 'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913', 'path': '0000-0001-9884-1913', 'host': 'orcid.org'}, 'source-name': {'value': 'Crossref'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 150776871, 'path': '/0000-0002-4779-5870/work/150776871', 'title': {'title': {'value': 'Detection of acute coronary occlusion with a novel mobile electrocardiogram device: a pilot study'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'European Heart Journal - Digital Health'}, 'short-description': None, 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2024'}, 'month': {'value': '03'}, 'day': {'value': '18'}}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.1093/ehjdh/ztae002', 'external-id-normalized': {'value': '10.1093/ehjdh/ztae002', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1093/ehjdh/ztae002'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1093/ehjdh/ztae002'}, 'contributors': {'contributor': [{'contributor-orcid': None, 'credit-name': {'value': 'Alejandra Zepeda-Echavarria'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger R van de Leur'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Melle Vessies'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Nynke M de Vries'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Meike van Sleuwen'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger J Hassink'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Thierry X Wildbergh'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'J L van Doorn'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rien van der Zee'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Pieter A Doevendans'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Joris E N Jaspers'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'René van Es'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1699382535778}, 'last-modified-date': {'value': 1705938624356}, 'source': {'source-orcid': None, 'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913', 'path': '0000-0001-9884-1913', 'host': 'orcid.org'}, 'source-name': {'value': 'Crossref'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 146146303, 'path': '/0000-0002-4779-5870/work/146146303', 'title': {'title': {'value': 'Automatic triage of twelve-lead electrocardiograms using deep convolutional neural networks: a first implementation study'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'European Heart Journal - Digital Health'}, 'short-description': None, 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2024'}, 'month': {'value': '01'}, 'day': {'value': '22'}}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.1093/ehjdh/ztad070', 'external-id-normalized': {'value': '10.1093/ehjdh/ztad070', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1093/ehjdh/ztad070'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1093/ehjdh/ztad070'}, 'contributors': {'contributor': [{'contributor-orcid': None, 'credit-name': {'value': 'Rutger R van de Leur'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Meike T G M van Sleuwen'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Peter-Paul M Zwetsloot'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Pim van der Harst'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Pieter A Doevendans'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger J Hassink'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'René van Es'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1701992273294}, 'last-modified-date': {'value': 1702211876556}, 'source': {'source-orcid': None, 'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913', 'path': '0000-0001-9884-1913', 'host': 'orcid.org'}, 'source-name': {'value': 'Crossref'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 148295188, 'path': '/0000-0002-4779-5870/work/148295188', 'title': {'title': {'value': 'Deep representation learning of electrocardiogram reveals novel insights in cardiac structure and functions and connections to cardiovascular diseases'}, 'subtitle': None, 'translated-title': None}, 'journal-title': None, 'short-description': None, 'citation': None, 'type': 'preprint', 'publication-date': {'year': {'value': '2023'}, 'month': {'value': '12'}, 'day': {'value': '07'}}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.1101/2023.12.05.23299459', 'external-id-normalized': {'value': '10.1101/2023.12.05.23299459', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1101/2023.12.05.23299459'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1101/2023.12.05.23299459'}, 'contributors': {'contributor': [{'contributor-orcid': None, 'credit-name': {'value': 'Ming Wai Yeung'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger R van de Leur'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Jan Walter Benjamins'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Melle B. Vessies'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Bram Ruijsink'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Esther Puyol-Antón'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'J. Peter van Tintelen'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Niek Verweij'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rene van Es'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Pim van der Harst'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1694474635099}, 'last-modified-date': {'value': 1694716553955}, 'source': {'source-orcid': None, 'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913', 'path': '0000-0001-9884-1913', 'host': 'orcid.org'}, 'source-name': {'value': 'Crossref'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 142154236, 'path': '/0000-0002-4779-5870/work/142154236', 'title': {'title': {'value': 'DCM-PROGRESS: predicting end-stage heart failure in non-ischemic dilated cardiomyopathy patients'}, 'subtitle': None, 'translated-title': None}, 'journal-title': None, 'short-description': None, 'citation': None, 'type': 'preprint', 'publication-date': {'year': {'value': '2023'}, 'month': {'value': '09'}, 'day': {'value': '11'}}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.1101/2023.09.10.23295251', 'external-id-normalized': {'value': '10.1101/2023.09.10.23295251', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1101/2023.09.10.23295251'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1101/2023.09.10.23295251'}, 'contributors': {'contributor': [{'contributor-orcid': None, 'credit-name': {'value': 'A F Schmidt'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'P Leinveber'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'R Panovsky'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'L Soukup'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'P Machac'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'R R van de Leur'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'A Sammani'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'K Lekadir'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'A ter Riele'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'F W Asselbergs'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'M J Boonstra'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1727623379447}, 'last-modified-date': {'value': 1727623379447}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 168523555, 'path': '/0000-0002-4779-5870/work/168523555', 'title': {'title': {'value': 'Deep neural network-based clustering of deformation curves reveals novel disease features in PLN pathogenic variant carriers.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'The international journal of cardiovascular imaging'}, 'short-description': 'Echocardiographic deformation curves provide detailed information on myocardial function. Deep neural networks (DNNs) may enable automated detection of disease features in deformation curves, and improve the clinical assessment of these curves. We aimed to investigate whether an explainable DNN-based pipeline can be used to detect and visualize disease features in echocardiographic deformation curves of phospholamban (PLN) p.Arg14del variant carriers. A DNN was trained to discriminate PLN variant carriers (n\u2009=\u2009278) from control subjects (n\u2009=\u2009621) using raw deformation curves obtained by 2D-speckle tracking in the longitudinal axis. A visualization technique was used to identify the parts of these curves that were used by the DNN for classification. The PLN variant carriers were clustered according to the output of the visualization technique. The DNN showed excellent discriminatory performance (C-statistic 0.93 [95% CI 0.87-0.97]). We identified four clusters with PLN-associated disease features in the deformation curves. Two clusters showed previously described features: apical post-systolic shortening and reduced systolic strain. The two other clusters revealed novel features, both reflecting delayed relaxation. Additionally, a fifth cluster was identified containing variant carriers without disease features in the deformation curves, who were classified as controls by the DNN. This latter cluster had a very benign disease course regarding development of ventricular arrhythmias. Applying an explainable DNN-based pipeline to myocardial deformation curves enables automated detection and visualization of disease features. In PLN variant carriers, we discovered novel disease features which may improve individual risk stratification. Applying this approach to other diseases will further expand our knowledge on disease-specific deformation patterns. Overview of the deep neural network-based pipeline for feature detection in myocardial deformation curves. Firstly, phospholamban (PLN) p.Arg14del variant carriers and controls were selected and a deep neural network (DNN) was trained to detect the PLN variant carriers. Subsequently, a clustering-based approach was performed on the attention maps of the DNN, which revealed 4 distinct phenotypes of PLN variant carriers with different prognoses. Moreover, a cluster without features and a benign prognosis was detected.', 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2023'}, 'month': {'value': '08'}, 'day': {'value': '11'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '37566298', 'external-id-normalized': {'value': '37566298', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://pubmed.ncbi.nlm.nih.gov/37566298'}, 'external-id-relationship': 'self'}, {'external-id-type': 'pmc', 'external-id-value': 'PMC10673970', 'external-id-normalized': {'value': '10673970', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://europepmc.org/article/pmc/PMC10673970'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1007/s10 ...
# {'created-date': {'value': 1727623487414}, 'last-modified-date': {'value': 1727623487414}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 168523589, 'path': '/0000-0002-4779-5870/work/168523589', 'title': {'title': {'value': 'Detection of Ischemic ST-Segment Changes Using a Novel Handheld ECG Device in a Porcine Model.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'JACC Advances'}, 'short-description': '<h4>Background</h4>Portable, smartphone-sized electrocardiography (ECG) has the potential to reduce time to treatment for patients suffering acute cardiac ischemia, thereby lowering the morbidity and mortality. In the UMC Utrecht, a portable, smartphone-sized, multi-lead precordial ECG recording device (miniECG 1.0, UMC Utrecht) was developed.<h4>Objectives</h4>The purpose of this study was to investigate the ability of the miniECG to capture ischemic ECG changes in a porcine coronary occlusion model.<h4>Methods</h4>In 8 animals, antero-septal myocardial infarction was induced by 75-minute occlusion of the left anterior descending artery, after the first or second diagonal. MiniECG and 12-lead ECG recordings were acquired simultaneously before, during and after coronary artery occlusion and ST-segment deviation was evaluated.<h4>Results</h4>During the complete occlusion and reperfusion period, miniECG showed large ST-segment deviation in comparison to 12-lead ECG. MiniECG ST-segment deviation was observed within 1\xa0minute for most animals. The miniECG was positive for ischemia (ie, ST-segment deviation\xa0≥1\xa0mm) for 99.7% (Q1-Q3: 99.6%-99.9%) of the occlusion time, while the 12-lead was only positive for 79.8% (Q1-Q3: 81.1%-98.7%) of the time (<i>P</i>\xa0=\xa00.018). ST-segment deviation reached maxima of 10.5\xa0mm [95%\xa0CI: 6.5-14.5\xa0mm] vs 5.0\xa0mm [95%\xa0CI: 2.0-8.0\xa0mm] for the miniECG vs 12-lead ECG, respectively.<h4>Conclusions</h4>MiniECG ST-segment deviation was observed early and was of large magnitude during 75 minutes of porcine transmural antero-septal infarction. The miniECG was positive for ischemia for the complete occlusion\xa0period. These findings demonstrate the potential of the miniECG in the detection of cardiac ischemia. Although clinical research is required, data suggests that the miniECG is a promising tool for the detection of cardiac ischemia.', 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2023'}, 'month': {'value': '07'}, 'day': {'value': '19'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '38939006', 'external-id-normalized': {'value': '38939006', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://pubmed.ncbi.nlm.nih.gov/38939006'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1016/j.jacadv.2023.100410', 'external-id-normalized': {'value': '10.1016/j.jacadv.2023.100410', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1016/j.jacadv.2023.100410'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1016/j.jacadv.2023.100410'}, 'contributors': {'contributor': [{'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'de Vries NM'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Zepeda-Echavarria A'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': ...
# {'created-date': {'value': 1686071135621}, 'last-modified-date': {'value': 1688742037297}, 'source': {'source-orcid': None, 'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913', 'path': '0000-0001-9884-1913', 'host': 'orcid.org'}, 'source-name': {'value': 'Crossref'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 136425431, 'path': '/0000-0002-4779-5870/work/136425431', 'title': {'title': {'value': 'Electrocardiogram Devices for Home Use: Technological and Clinical Scoping Review'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'JMIR Cardio'}, 'short-description': None, 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2023'}, 'month': {'value': '07'}, 'day': {'value': '07'}}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.2196/44003', 'external-id-normalized': {'value': '10.2196/44003', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.2196/44003'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.2196/44003'}, 'contributors': {'contributor': [{'contributor-orcid': None, 'credit-name': {'value': 'Alejandra Zepeda-Echavarria'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger R van de Leur'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Meike van Sleuwen'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger J Hassink'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Thierry X Wildbergh'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Pieter A Doevendans'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Joris Jaspers'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'René van Es'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1727623666511}, 'last-modified-date': {'value': 1727623666511}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 168523635, 'path': '/0000-0002-4779-5870/work/168523635', 'title': {'title': {'value': 'Machine-learning-derived heart and brain age are independently associated with cognition.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'European Journal of Neurology'}, 'short-description': "<h4>Background and purpose</h4>A heart age biomarker has been developed using deep neural networks applied to electrocardiograms. Whether this biomarker is associated with cognitive function was investigated.<h4>Methods</h4>Using 12-lead electrocardiograms, heart age was estimated for a population-based sample (N\u2009=\u20097779, age 40-85\u2009years, 45.3% men). Associations between heart delta age (HDA) and cognitive test scores were studied adjusted for cardiovascular risk factors. In addition, the relationship between HDA, brain delta age (BDA) and cognitive test scores was investigated in mediation analysis.<h4>Results</h4>Significant associations between HDA and the Word test, Digit Symbol Coding Test and tapping test scores were found. HDA was correlated with BDA (Pearson's r\u2009=\u20090.12, p\u2009=\u20090.0001). Moreover, 13% (95% confidence interval 3-36) of the HDA effect on the tapping test score was mediated through BDA.<h4>Discussion</h4>Heart delta age, representing the cumulative effects of life-long exposures, was associated with brain age. HDA was associated with cognitive function that was minimally explained through BDA.", 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2023'}, 'month': {'value': '06'}, 'day': {'value': '12'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '37254942', 'external-id-normalized': {'value': '37254942', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://pubmed.ncbi.nlm.nih.gov/37254942'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1111/ene.15902', 'external-id-normalized': {'value': '10.1111/ene.15902', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1111/ene.15902'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1111/ene.15902'}, 'contributors': {'contributor': [{'contributor-orcid': {'uri': 'https://orcid.org/0000-0002-8972-3621', 'path': '0000-0002-8972-3621', 'host': None}, 'credit-name': {'value': 'Olena Iakunchykova'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Schirmer H'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Vangberg T'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Wang Y'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Benavente ED'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'van Es R'}, 'contributor-email ...
# {'created-date': {'value': 1665788986900}, 'last-modified-date': {'value': 1677004730342}, 'source': {'source-orcid': None, 'source-client-id': {'uri': 'https://orcid.org/client/0000-0001-9884-1913', 'path': '0000-0001-9884-1913', 'host': 'orcid.org'}, 'source-name': {'value': 'Crossref'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 120794917, 'path': '/0000-0002-4779-5870/work/120794917', 'title': {'title': {'value': 'Electrocardiogram-based deep learning improves outcome prediction following cardiac resynchronization therapy'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'European Heart Journal'}, 'short-description': None, 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2023'}, 'month': {'value': '02'}, 'day': {'value': '21'}}, 'external-ids': {'external-id': [{'external-id-type': 'doi', 'external-id-value': '10.1093/eurheartj/ehac617', 'external-id-normalized': {'value': '10.1093/eurheartj/ehac617', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1093/eurheartj/ehac617'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1093/eurheartj/ehac617'}, 'contributors': {'contributor': [{'contributor-orcid': None, 'credit-name': {'value': 'Philippe C Wouters'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger R van de Leur'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Melle B Vessies'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Antonius M W van Stipdonk'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Mohammed A Ghossein'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Rutger J Hassink'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Pieter A Doevendans'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Pim van der Harst'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Alexander H Maass'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Frits W Prinzen'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Kevin Vernooy'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'Mathias Meine'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': None, 'credit-name': {'value': 'René van Es'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1727623695414}, 'last-modified-date': {'value': 1727623695414}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 168523640, 'path': '/0000-0002-4779-5870/work/168523640', 'title': {'title': {'value': 'Variational auto-encoders improve explainability over currently employed heatmap methods for deep learning-based interpretation of the electrocardiogram.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'European Heart Journal Digital Health'}, 'short-description': None, 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2022'}, 'month': {'value': '10'}, 'day': {'value': '26'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '36710900', 'external-id-normalized': {'value': '36710900', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://pubmed.ncbi.nlm.nih.gov/36710900'}, 'external-id-relationship': 'self'}, {'external-id-type': 'pmc', 'external-id-value': 'PMC9779792', 'external-id-normalized': {'value': '9779792', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://europepmc.org/article/pmc/PMC9779792'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1093/ehjdh/ztac063', 'external-id-normalized': {'value': '10.1093/ehjdh/ztac063', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1093/ehjdh/ztac063'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://europepmc.org/articles/PMC9779792'}, 'contributors': {'contributor': [{'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'van de Leur RR'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'Hassink RJ'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': 'https://orcid.org/0000-0001-9950-4388', 'path': '0000-0001-9950-4388', 'host': None}, 'credit-name': {'value': 'René van Es'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}]}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1727623654865}, 'last-modified-date': {'value': 1727623654865}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 168523631, 'path': '/0000-0002-4779-5870/work/168523631', 'title': {'title': {'value': 'Life-threatening ventricular arrhythmia prediction in patients with dilated cardiomyopathy using explainable electrocardiogram-based deep neural networks.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'Europace'}, 'short-description': "<h4>Aims</h4>While electrocardiogram (ECG) characteristics have been associated with life-threatening ventricular arrhythmias (LTVA) in dilated cardiomyopathy (DCM), they typically rely on human-derived parameters. Deep neural networks (DNNs) can discover complex ECG patterns, but the interpretation is hampered by their 'black-box' characteristics. We aimed to detect DCM patients at risk of LTVA using an inherently explainable DNN.<h4>Methods and results</h4>In this two-phase study, we first developed a variational autoencoder DNN on more than 1 million 12-lead median beat ECGs, compressing the ECG into 21 different factors (F): FactorECG. Next, we used two cohorts with a combined total of 695 DCM patients and entered these factors in a Cox regression for the composite LTVA outcome, which was defined as sudden cardiac arrest, spontaneous sustained ventricular tachycardia, or implantable cardioverter-defibrillator treated ventricular arrhythmia. Most patients were male (n\u2009=\u2009442, 64%) with a median age of 54 years [interquartile range (IQR) 44-62], and median left ventricular ejection fraction of 30% (IQR 23-39). A total of 115 patients (16.5%) reached the study outcome. Factors F8 (prolonged PR-interval and P-wave duration, P\u2009<\u20090.005), F15 (reduced P-wave height, P\u2009=\u20090.04), F25 (increased right bundle branch delay, P\u2009=\u20090.02), F27 (P-wave axis P\u2009<\u20090.005), and F32 (reduced QRS-T voltages P\u2009=\u20090.03) were significantly associated with LTVA.<h4>Conclusion</h4>Inherently explainable DNNs can detect patients at risk of LTVA which is mainly driven by P-wave abnormalities.", 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2022'}, 'month': {'value': '10'}, 'day': {'value': '01'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '35762524', 'external-id-normalized': {'value': '35762524', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://pubmed.ncbi.nlm.nih.gov/35762524'}, 'external-id-relationship': 'self'}, {'external-id-type': 'pmc', 'external-id-value': 'PMC9559909', 'external-id-normalized': {'value': '9559909', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://europepmc.org/article/pmc/PMC9559909'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1093/europace/euac054', 'external-id-normalized': {'value': '10.1093/europace/euac054', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1093/europace/euac054'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://europepmc.org/articles/PMC9559909'}, 'contributors': {'contributor': [{'contributor-orcid': {'uri': 'https://orcid.org/0000-0002-5557-9342', 'path': '0000-0002-5557-9342', 'host': None}, 'credit-name': {'value': 'A. Sammani'}, 'contributor-email': None, 'contributor-attributes': {'contributor-sequence': None, 'contributor-role': 'author'}}, {'contributor-orcid': {'uri': None, 'path': None, 'host': None}, 'credit-name': {'value': 'van de Leur RR'}, 'contributor-email': None, 'contributor-attributes': {'cont ...
# ...
# {'created-date': {'value': 1643904340272}, 'last-modified-date': {'value': 1643904340272}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 107577680, 'path': '/0000-0002-4779-5870/work/107577680', 'title': {'title': {'value': 'Automatic Triage of 12-Lead ECGs Using Deep Convolutional Neural Networks.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'Journal of the American Heart Association'}, 'short-description': 'BACKGROUND The correct interpretation of the ECG is pivotal for the accurate diagnosis of many cardiac abnormalities, and conventional computerized interpretation has not been able to reach physician-level accuracy in detecting (acute) cardiac abnormalities. This study aims to develop and validate a deep neural network for comprehensive automated ECG triage in daily practice. METHODS AND RESULTS We developed a 37-layer convolutional residual deep neural network on a data set of free-text physician-annotated 12-lead ECGs. The deep neural network was trained on a data set with 336.835 recordings from 142.040 patients and validated on an independent validation data set (n=984), annotated by a panel of 5 cardiologists electrophysiologists. The 12-lead ECGs were acquired in all noncardiology departments of the University Medical Center Utrecht. The algorithm learned to classify these ECGs into the following 4 triage categories: normal, abnormal not acute, subacute, and acute. Discriminative performance is presented with overall and category-specific concordance statistics, polytomous discrimination indexes, sensitivities, specificities, and positive and negative predictive values. The patients in the validation data set had a mean age of 60.4\xa0years and 54.3% were men. The deep neural network showed excellent overall discrimination with an overall concordance statistic of 0.93 (95% CI, 0.92-0.95) and a polytomous discriminatory index of 0.83 (95% CI, 0.79-0.87). CONCLUSIONS This study demonstrates that an end-to-end deep neural network can be accurately trained on unstructured free-text physician annotations and used to consistently triage 12-lead ECGs. When further fine-tuned with other clinical outcomes and externally validated in clinical practice, the demonstrated deep learning-based ECG interpretation can potentially improve time to treatment and decrease healthcare burden.', 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2020'}, 'month': {'value': '05'}, 'day': {'value': '14'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '32406296', 'external-id-normalized': {'value': '32406296', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://www.ncbi.nlm.nih.gov/pubmed/32406296'}, 'external-id-relationship': 'self'}, {'external-id-type': 'pmc', 'external-id-value': 'PMC7660886', 'external-id-normalized': {'value': '7660886', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://europepmc.org/articles/PMC7660886'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1161/jaha.119.015138', 'external-id-normalized': {'value': '10.1161/jaha.119.015138', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1161/jaha.119.015138'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://europepmc.org/articles/PMC7660886'}, 'contributors': {'contributor': []}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1643904383216}, 'last-modified-date': {'value': 1643904383216}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 107577713, 'path': '/0000-0002-4779-5870/work/107577713', 'title': {'title': {'value': 'Incorporating repeated measurements into prediction models in the critical care setting: a framework, systematic review and meta-analysis.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'BMC medical research methodology'}, 'short-description': 'BACKGROUND:The incorporation of repeated measurements into multivariable prediction research may greatly enhance predictive performance. However, the methodological possibilities vary widely and a structured overview of the possible and utilized approaches lacks. Therefore, we [1] propose a structured framework for these approaches, [2] determine what methods are currently used to incorporate repeated measurements in prediction research in the critical care setting and, where possible, [3] assess the added discriminative value of incorporating repeated measurements. METHODS:The proposed framework consists of three domains: the observation window (static or dynamic), the processing of the raw data (raw data modelling, feature extraction and reduction) and the type of modelling. A systematic review was performed to identify studies which incorporate repeated measurements to predict (e.g. mortality) in the critical care setting. The within-study difference in c-statistics between models with versus without repeated measurements were obtained and pooled in a meta-analysis. RESULTS:From the 2618 studies found, 29 studies incorporated multiple repeated measurements. The annual number of studies with repeated measurements increased from 2.8/year (2000-2005) to 16.0/year (2016-2018). The majority of studies that incorporated repeated measurements for prediction research used a dynamic observation window, and extracted features directly from the data. Differences in c statistics ranged from -\u20090.048 to 0.217 in favour of models that utilize repeated measurements. CONCLUSIONS:Repeated measurements are increasingly common to predict events in the critical care domain, but their incorporation is lagging. A framework of possible approaches could aid researchers to optimize future prediction models.', 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2019'}, 'month': {'value': '10'}, 'day': {'value': '26'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '31655567', 'external-id-normalized': {'value': '31655567', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://www.ncbi.nlm.nih.gov/pubmed/31655567'}, 'external-id-relationship': 'self'}, {'external-id-type': 'pmc', 'external-id-value': 'PMC6815391', 'external-id-normalized': {'value': '6815391', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://europepmc.org/articles/PMC6815391'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1186/s12874-019-0847-0', 'external-id-normalized': {'value': '10.1186/s12874-019-0847-0', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1186/s12874-019-0847-0'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://europepmc.org/articles/PMC6815391'}, 'contributors': {'contributor': []}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1643904373432}, 'last-modified-date': {'value': 1643904373432}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 107577706, 'path': '/0000-0002-4779-5870/work/107577706', 'title': {'title': {'value': '3D Myocardial Scar Prediction Model Derived from Multimodality Analysis of Electromechanical Mapping and Magnetic Resonance Imaging.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'Journal of cardiovascular translational research'}, 'short-description': 'Many cardiac catheter interventions require accurate discrimination between healthy and infarcted myocardia. The gold standard for infarct imaging is late gadolinium-enhanced MRI (LGE-MRI), but during cardiac procedures electroanatomical or electromechanical mapping (EAM or EMM, respectively) is usually employed. We aimed to improve the ability of EMM to identify myocardial infarction by combining multiple EMM parameters in a statistical model. From a porcine infarction model, 3D electromechanical maps were 3D registered to LGE-MRI. A multivariable mixed-effects logistic regression model was fitted to predict the presence of infarct based on EMM parameters. Furthermore, we correlated feature-tracking strain parameters to EMM measures of local mechanical deformation. We registered 787 EMM points from 13 animals to the corresponding MRI locations. The mean registration error was 2.5\u2009±\u20091.16\xa0mm. Our model showed a strong ability to predict the presence of infarction (C-statistic\u2009=\u20090.85). Strain parameters were only weakly correlated to EMM measures. The model is accurate in discriminating infarcted from healthy myocardium. Unipolar and bipolar voltages were the strongest predictors.', 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2019'}, 'month': {'value': '07'}, 'day': {'value': '23'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '31338795', 'external-id-normalized': {'value': '31338795', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://www.ncbi.nlm.nih.gov/pubmed/31338795'}, 'external-id-relationship': 'self'}, {'external-id-type': 'pmc', 'external-id-value': 'PMC6854049', 'external-id-normalized': {'value': '6854049', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://europepmc.org/articles/PMC6854049'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1007/s12265-019-09899-w', 'external-id-normalized': {'value': '10.1007/s12265-019-09899-w', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1007/s12265-019-09899-w'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://europepmc.org/articles/PMC6854049'}, 'contributors': {'contributor': []}, 'language-code': None, 'country': None, 'visibility': 'public'}
# {'created-date': {'value': 1643904318881}, 'last-modified-date': {'value': 1643904318881}, 'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870', 'path': '0000-0002-4779-5870', 'host': 'orcid.org'}, 'source-client-id': None, 'source-name': {'value': 'Rutger R van de Leur'}, 'assertion-origin-orcid': None, 'assertion-origin-client-id': None, 'assertion-origin-name': None}, 'put-code': 107577663, 'path': '/0000-0002-4779-5870/work/107577663', 'title': {'title': {'value': 'Delirium in critically ill patients.'}, 'subtitle': None, 'translated-title': None}, 'journal-title': {'value': 'Handbook of clinical neurology'}, 'short-description': 'Delirium is common in critically ill patients and associated with increased length of stay in the intensive care unit (ICU) and long-term cognitive impairment. The pathophysiology of delirium has been explained by neuroinflammation, an aberrant stress response, neurotransmitter imbalances, and neuronal network alterations. Delirium develops mostly in vulnerable patients (e.g., elderly and cognitively impaired) in the throes of a critical illness. Delirium is by definition due to an underlying condition and can be identified at ICU admission using prediction models. Treatment of delirium can be improved with frequent monitoring, as early detection and subsequent treatment of the underlying condition can improve outcome. Cautious use or avoidance of benzodiazepines may reduce the likelihood of developing delirium. Nonpharmacologic strategies with early mobilization, reducing causes for sleep deprivation, and reorientation measures may be effective in the prevention of delirium. Antipsychotics are effective in treating hallucinations and agitation, but do not reduce the duration of delirium. Combined pain, agitation, and delirium protocols seem to improve the outcome of critically ill patients and may reduce delirium incidence.', 'citation': None, 'type': 'journal-article', 'publication-date': {'year': {'value': '2017'}, 'month': {'value': '01'}, 'day': {'value': '01'}}, 'external-ids': {'external-id': [{'external-id-type': 'pmid', 'external-id-value': '28190430', 'external-id-normalized': {'value': '28190430', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://www.ncbi.nlm.nih.gov/pubmed/28190430'}, 'external-id-relationship': 'self'}, {'external-id-type': 'doi', 'external-id-value': '10.1016/b978-0-444-63599-0.00025-9', 'external-id-normalized': {'value': '10.1016/b978-0-444-63599-0.00025-9', 'transient': True}, 'external-id-normalized-error': None, 'external-id-url': {'value': 'https://doi.org/10.1016/b978-0-444-63599-0.00025-9'}, 'external-id-relationship': 'self'}]}, 'url': {'value': 'https://doi.org/10.1016/B978-0-444-63599-0.00025-9'}, 'contributors': {'contributor': []}, 'language-code': None, 'country': None, 'visibility': 'public'}

# %%
work
# Out:
# {'created-date': {'value': 1643904318881},
#  'last-modified-date': {'value': 1643904318881},
#  'source': {'source-orcid': {'uri': 'https://orcid.org/0000-0002-4779-5870',
#    'path': '0000-0002-4779-5870',
#    'host': 'orcid.org'},
#   'source-client-id': None,
#   'source-name': {'value': 'Rutger R van de Leur'},
#   'assertion-origin-orcid': None,
#   'assertion-origin-client-id': None,
#   'assertion-origin-name': None},
#  'put-code': 107577663,
#  'path': '/0000-0002-4779-5870/work/107577663',
#  'title': {'title': {'value': 'Delirium in critically ill patients.'},
#   'subtitle': None,
#   'translated-title': None},
#  'journal-title': {'value': 'Handbook of clinical neurology'},
#  'short-description': 'Delirium is common in critically ill patients and associated with increased length of stay in the intensive care unit (ICU) and long-term cognitive impairment. The pathophysiology of delirium has been explained by neuroinflammation, an aberrant stress response, neurotransmitter imbalances, and neuronal network alterations. Delirium develops mostly in vulnerable patients (e.g., elderly and cognitively impaired) in the throes of a critical illness. Delirium is by definition due to an underlying condition and can be identified at ICU admission using prediction models. Treatment of delirium can be improved with frequent monitoring, as early detection and subsequent treatment of the underlying condition can improve outcome. Cautious use or avoidance of benzodiazepines may reduce the likelihood of developing delirium. Nonpharmacologic strategies with early mobilization, reducing causes for sleep deprivation, and reorientation measures may be effective in the prevention of delirium. Antipsychotics are effective in treating hallucinations and agitation, but do not reduce the duration of delirium. Combined pain, agitation, and delirium protocols seem to improve the outcome of critically ill patients and may reduce delirium incidence.',
#  'citation': None,
#  'type': 'journal-article',
#  'publication-date': {'year': {'value': '2017'},
#   'month': {'value': '01'},
#   'day': {'value': '01'}},
#  'external-ids': {'external-id': [{'external-id-type': 'pmid',
#     'external-id-value': '28190430',
#     'external-id-normalized': {'value': '28190430', 'transient': True},
#     'external-id-normalized-error': None,
#     'external-id-url': {'value': 'https://www.ncbi.nlm.nih.gov/pubmed/28190430'},
#     'external-id-relationship': 'self'},
#    {'external-id-type': 'doi',
#     'external-id-value': '10.1016/b978-0-444-63599-0.00025-9',
#     'external-id-normalized': {'value': '10.1016/b978-0-444-63599-0.00025-9',
#      'transient': True},
#     'external-id-normalized-error': None,
#     'external-id-url': {'value': 'https://doi.org/10.1016/b978-0-444-63599-0.00025-9'},
#     'external-id-relationship': 'self'}]},
#  'url': {'value': 'https://doi.org/10.1016/B978-0-444-63599-0.00025-9'},
#  'contributors': {'contributor': []},
#  'language-code': None,
#  'country': None,
#  'visibility': 'public'}

# %%
with open('output.bib', 'w') as bibfile:
    for citation in citations:
        bibfile.write(citation)
        bibfile.write('\n')
